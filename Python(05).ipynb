# %%
o=int(input("Enter the no"))
x=int(o/2)+1
st=1
sp=int(o/2)
for i in range(o+1)[1::]:
    if i<x:
        for i in range(sp):
            print(" ",end="")
        for i in range(st):
            print("*",end="")
        for i in range(sp):
            print(" ",end="")           
        print()
        st+=2
        sp-=1
    elif i==x:
        for i in range(o):
            print("*",end="")
        print()  
    else:
        sp+=1
        st-=2
        for i in range(sp):
            print(" ",end="")
        for i in range(st):
            print("*",end="")
        for i in range(sp):
            print(" ",end="")
        print()
# Out:
# Enter the no99
#                                                  *
#                                                 ***
#                                                *****
#                                               *******
#                                              *********
#                                             ***********
#                                            *************
#                                           ***************
#                                          *****************
#                                         *******************
#                                        *********************
#                                       ***********************
#                                      *************************
#                                     ***************************
#                                    *****************************
#                                   *******************************
# ...
